# %% [markdown]
# ***Name: SADDAM HUSSAIN***
#
# ***REG ID: GO_STP_6834***
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Predict Loan Eligibility for Dream Housing Finance company
#
# Dream Housing Finance company deals in all kinds of home loans. They have presence across all urban, semi urban and rural areas. Customer first applies for home loan and after that company validates the customer eligibility for loan.
#
# Company wants to automate the loan eligibility process (real time) based on customer detail provided while filling online application form. These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have provided a dataset to identify the customers segments that are eligible for loan amount so that they can specifically target these customers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn

# %%
df = pd.read_csv('/content/train_u6lujuX_CVtuZ9i.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  ...  Loan_Amount_Term  Credit_History
# count       614.000000         614.000000  ...         600.00000      564.000000
# mean       5403.459283        1621.245798  ...         342.00000        0.842199
# std        6109.041673        2926.248369  ...          65.12041        0.364878
# min         150.000000           0.000000  ...          12.00000        0.000000
# 25%        2877.500000           0.000000  ...         360.00000        1.000000
# 50%        3812.500000        1188.500000  ...         360.00000        1.000000
# 75%        5795.000000        2297.250000  ...         360.00000        1.000000
# max       81000.000000       41667.000000  ...         480.00000        1.000000
#
# [8 rows x 5 columns]

# %%
df.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df.Loan_Amount_Term.unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Loan Amount
df.LoanAmount.fillna(df.LoanAmount.median(), inplace=True)

# %%
# Loan Amount Term
df.Loan_Amount_Term.fillna(df.Loan_Amount_Term.median(), inplace = True)

# %%
#df['Gender'] = df['Gender'].fillna(df['Gender'].mode)
df.Gender.fillna(df.Gender.value_counts().index[0], inplace = True)

# %%
df.Married.fillna(df.Married.value_counts().index[0], inplace = True)
df.Dependents.fillna(df.Dependents.value_counts().index[0], inplace = True)

# %%
df.Credit_History.fillna(df.Credit_History.value_counts().index[0], inplace = True)
df.Self_Employed.fillna(df.Self_Employed.value_counts().index[0], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(df, hue = 'Loan_Status')

plt.show()

# %%
plt.figure(figsize = (20,10))
sns.swarmplot(x = 'Education', y = 'ApplicantIncome', data = df)

# %%
sns.boxplot(x = 'Property_Area', y = 'LoanAmount', data = df)

# %%
sns.stripplot( x = 'Loan_Status', y = 'ApplicantIncome', data = df)

# %%
sns.scatterplot(x = 'LoanAmount', y = 'ApplicantIncome',hue = 'Loan_Status', data = df)

# %%
sns.barplot(data = df)

# %% [markdown]
# # Data Conversion

# %%
df.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
#df.Education.unique()
df.drop('Loan_ID', axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
cat_cols = ['Gender', 'Married', 'Education', 'Self_Employed', 'Loan_Status']
df = pd.get_dummies(df, columns = cat_cols, drop_first = True)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

df['Property_Area'] = label_encoder.fit_transform(df['Property_Area'])

# %%
df['Dependents'] = df['Dependents'].replace('3+', 3).astype('int')

# %%
df.Dependents.unique()
# Out:
# array([0, 1, 2, 3])

# %%
df.head()
# Out:
#    Dependents  ApplicantIncome  ...  Self_Employed_Yes  Loan_Status_Y
# 0           0             5849  ...                  0              1
# 1           1             4583  ...                  0              0
# 2           0             3000  ...                  1              1
# 3           0             2583  ...                  0              1
# 4           0             6000  ...                  0              1
#
# [5 rows x 12 columns]

# %%
import seaborn as sns

plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True, linewidths=1)

# %%
df.corrwith(df['Loan_Status_Y']).plot.bar(figsize=(10,5),title = 'Correlation with Target', fontsize = 10, rot = 90,grid = True)

# %% [markdown]
# # Data Split

# %%
X = df.drop('Loan_Status_Y', axis=1)
y = df.Loan_Status_Y

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %% [markdown]
# # Model - DT MODEL

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=5)

# %%
model = dt.fit(X_train, y_train)

# %% [markdown]
# # Prediction

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7398373983739838

# %% [markdown]
# # Confusion Matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[20, 20],
#        [12, 71]])

# %%
#Plot Decision tree
from sklearn import tree

# %%
tree.plot_tree(model)
# Out:
# [Text(143.51820652173913, 213.55714285714285, 'X[5] <= 0.5\ngini = 0.427\nsamples = 491\nvalue = [152, 339]'),
#  Text(60.652173913043484, 205.79142857142858, 'X[2] <= 8115.0\ngini = 0.111\nsamples = 68\nvalue = [64, 4]'),
#  Text(48.52173913043479, 198.0257142857143, 'X[3] <= 160.5\ngini = 0.087\nsamples = 66\nvalue = [63, 3]'),
#  Text(38.81739130434783, 190.26, 'X[4] <= 240.0\ngini = 0.037\nsamples = 53\nvalue = [52, 1]'),
#  Text(33.96521739130435, 182.4942857142857, 'X[0] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(29.11304347826087, 174.72857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(38.81739130434783, 174.72857142857143, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(43.66956521739131, 182.4942857142857, 'gini = 0.0\nsamples = 47\nvalue = [47, 0]'),
#  Text(58.22608695652174, 190.26, 'X[3] <= 172.0\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(53.37391304347827, 182.4942857142857, 'X[6] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(48.52173913043479, 174.72857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(58.22608695652174, 174.72857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(63.07826086956522, 182.4942857142857, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(72.78260869565219, 198.0257142857143, 'X[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(67.9304347826087, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(77.63478260869566, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(226.3842391304348, 205.79142857142858, 'X[2] <= 9650.5\ngini = 0.33\nsamples = 423\nvalue = [88, 335]'),
#  Text(175.5880434782609, 198.0257142857143, 'X[6] <= 0.5\ngini = 0.321\nsamples = 418\nvalue = [84, 334]'),
#  Text(103.10869565217392, 190.26, 'X[3] <= 302.0\ngini = 0.419\nsamples = 124\nvalue = [37, 87]'),
#  Text(84.91304347826087, 182.4942857142857, 'X[3] <= 85.5\ngini = 0.394\nsamples = 115\nvalue = [31, 84]'),
#  Text(67.9304347826087, 174.72857142857143, 'X[3] <= 51.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(63.07826086956522, 166.96285714285713, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(72.78260869565219, 166.96285714285713, 'X[8] <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(67.9304347826087, 159.19714285714286, 'X[3] <= 60.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(63.07826086956522, 151.43142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(72.78260869565219, 151.43142857142857, 'X[7] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(67.9304347826087, 143.66571428571427, 'X[3] <= 76.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(63.07826086956522, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(72.78260869565219, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(77.63478260869566, 143.66571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(77.63478260869566, 159.19714285714286, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(101.89565217391305, 174.72857142857143, 'X[2] <= 3026.5\ngini = 0.352\nsamples = 101\nvalue = [23, 78]'),
#  Text(92.19130434782609, 166.96285714285713, 'X[1] <= 587.5\ngini = 0.393\nsamples = 82\nvalue = [22, 60]'),
#  Text(87.33913043478262, 159.19714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.04347826086958, 159.19714285714286, 'X[1] <= 18596.0\ngini = 0.384\nsamples = 81\nvalue = [21, 60]'),
#  Text(92.19130434782609, 151.43142857142857, 'X[4] <= 420.0\ngini = 0.375\nsamples = 80\nvalue = [20, 60]'),
#  Text(87.33913043478262, 143.66571428571427, 'X[2] <= 2992.5\ngini = 0.365\nsamples = 79\nvalue = [19, 60]'),
#  Text(82.48695652173913, 135.89999999999998, 'X[1] <= 6391.5\ngini = 0.355\nsamples = 78\nvalue = [18, 60]'),
#  Text(53.37391304347827, 128.1342857142857, 'X[2] <= 1603.0\ngini = 0.382\nsamples = 66\nvalue = [17, 49]'),
#  Text(26.686956521739134, 120.36857142857143, 'X[1] <= 3645.0\ngini = 0.456\nsamples = 37\nvalue = [13, 24]'),
#  Text(14.556521739130435, 112.60285714285713, 'X[1] <= 3172.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(9.704347826086957, 104.83714285714285, 'X[1] <= 2783.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(4.852173913043479, 97.07142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(14.556521739130435, 97.07142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(19.408695652173915, 104.83714285714285, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(38.81739130434783, 112.60285714285713, 'X[3] <= 178.5\ngini = 0.375\nsamples = 28\nvalue = [7, 21]'),
#  Text(33.96521739130435, 104.83714285714285, 'X[2] <= 1427.0\ngini = 0.346\nsamples = 27\nvalue = [6, 21]'),
#  Text(24.260869565217394, 97.07142857142857, 'X[1] <= 4525.0\ngini = 0.278\nsamples = 24\nvalue = [4, 20]'),
#  Text(19.408695652173915, 89.30571428571429, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(29.11304347826087, 89.30571428571429, 'X[1] <= 4943.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(19.408695652173915, 81.53999999999999, 'X[0] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(14.556521739130435, 73.7742857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(24.260869565217394, 73.7742857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(38.81739130434783, 81.53999999999999, 'X[9] <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(33.96521739130435, 73.7742857142857, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(43.66956521739131, 73.7742857142857, 'X[3] <= 131.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(38.81739130434783, 66.00857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(48.52173913043479, 66.00857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(43.66956521739131, 97.07142857142857, 'X[1] <= 4183.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(38.81739130434783, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(48.52173913043479, 89.30571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(43.66956521739131, 104.83714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(80.0608695652174, 120.36857142857143, 'X[3] <= 157.0\ngini = 0.238\nsamples = 29\nvalue = [4, 25]'),
#  Text(67.9304347826087, 112.60285714285713, 'X[2] <= 2816.0\ngini = 0.147\nsamples = 25\nvalue = [2, 23]'),
#  Text(58.22608695652174, 104.83714285714285, 'X[1] <= 3277.5\ngini = 0.083\nsamples = 23\nvalue = [1, 22]'),
#  Text(53.37391304347827, 97.07142857142857, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(63.07826086956522, 97.07142857142857, 'X[2] <= 2100.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(58.22608695652174, 89.30571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(67.9304347826087, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(77.63478260869566, 104.83714285714285, 'X[3] <= 123.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(72.78260869565219, 97.07142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(82.48695652173913, 97.07142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(92.19130434782609, 112.60285714285713, 'X[3] <= 184.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(87.33913043478262, 104.83714285714285, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(97.04347826086958, 104.83714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(111.60000000000001, 128.1342857142857, 'X[7] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(106.74782608695654, 120.36857142857143, 'X[1] <= 8600.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(101.89565217391305, 112.60285714285713, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(111.60000000000001, 112.60285714285713, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(116.45217391304348, 120.36857142857143, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(92.19130434782609, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.04347826086958, 143.66571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(101.89565217391305, 151.43142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(111.60000000000001, 166.96285714285713, 'X[9] <= 0.5\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(106.74782608695654, 159.19714285714286, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(116.45217391304348, 159.19714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(121.30434782608697, 182.4942857142857, 'X[0] <= 1.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(116.45217391304348, 174.72857142857143, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(126.15652173913044, 174.72857142857143, 'X[3] <= 345.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(121.30434782608697, 166.96285714285713, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(131.0086956521739, 166.96285714285713, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(248.06739130434784, 190.26, 'X[4] <= 60.0\ngini = 0.269\nsamples = 294\nvalue = [47, 247]'),
#  Text(238.3630434782609, 182.4942857142857, 'X[6] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(233.5108695652174, 174.72857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(243.21521739130438, 174.72857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(257.7717391304348, 182.4942857142857, 'X[3] <= 13.0\ngini = 0.261\nsamples = 291\nvalue = [45, 246]'),
#  Text(252.91956521739132, 174.72857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(262.6239130434783, 174.72857142857143, 'X[2] <= 7480.0\ngini = 0.257\nsamples = 290\nvalue = [44, 246]'),
#  Text(257.7717391304348, 166.96285714285713, 'X[4] <= 420.0\ngini = 0.253\nsamples = 289\nvalue = [43, 246]'),
#  Text(224.41304347826087, 159.19714285714286, 'X[3] <= 137.5\ngini = 0.243\nsamples = 282\nvalue = [40, 242]'),
#  Text(177.10434782608698, 151.43142857142857, 'X[2] <= 5708.0\ngini = 0.192\nsamples = 177\nvalue = [19, 158]'),
#  Text(172.2521739130435, 143.66571428571427, 'X[6] <= 1.5\ngini = 0.184\nsamples = 176\nvalue = [18, 158]'),
#  Text(145.56521739130437, 135.89999999999998, 'X[10] <= 0.5\ngini = 0.101\nsamples = 94\nvalue = [5, 89]'),
#  Text(131.0086956521739, 128.1342857142857, 'X[3] <= 126.0\ngini = 0.049\nsamples = 79\nvalue = [2, 77]'),
#  Text(126.15652173913044, 120.36857142857143, 'gini = 0.0\nsamples = 61\nvalue = [0, 61]'),
#  Text(135.8608695652174, 120.36857142857143, 'X[0] <= 2.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(131.0086956521739, 112.60285714285713, 'X[3] <= 127.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(126.15652173913044, 104.83714285714285, 'X[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(121.30434782608697, 97.07142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(131.0086956521739, 97.07142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(135.8608695652174, 104.83714285714285, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(140.7130434782609, 112.60285714285713, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(160.1217391304348, 128.1342857142857, 'X[1] <= 4755.0\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(155.26956521739132, 120.36857142857143, 'X[7] <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(150.41739130434783, 112.60285714285713, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(160.1217391304348, 112.60285714285713, 'X[1] <= 3901.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(155.26956521739132, 104.83714285714285, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(164.97391304347826, 104.83714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(164.97391304347826, 120.36857142857143, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(198.9391304347826, 135.89999999999998, 'X[2] <= 3798.0\ngini = 0.267\nsamples = 82\nvalue = [13, 69]'),
#  Text(194.08695652173915, 128.1342857142857, 'X[1] <= 1149.5\ngini = 0.237\nsamples = 80\nvalue = [11, 69]'),
#  Text(189.23478260869567, 120.36857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(198.9391304347826, 120.36857142857143, 'X[1] <= 3523.0\ngini = 0.221\nsamples = 79\nvalue = [10, 69]'),
#  Text(179.53043478260872, 112.60285714285713, 'X[2] <= 1621.5\ngini = 0.12\nsamples = 47\nvalue = [3, 44]'),
#  Text(174.67826086956524, 104.83714285714285, 'X[2] <= 1581.5\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(169.82608695652175, 97.07142857142857, 'X[2] <= 230.5\ngini = 0.128\nsamples = 29\nvalue = [2, 27]'),
#  Text(164.97391304347826, 89.30571428571429, 'X[1] <= 2457.0\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(160.1217391304348, 81.53999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(169.82608695652175, 81.53999999999999, 'X[3] <= 72.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(164.97391304347826, 73.7742857142857, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(174.67826086956524, 73.7742857142857, 'X[3] <= 77.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(169.82608695652175, 66.00857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(179.53043478260872, 66.00857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(174.67826086956524, 89.30571428571429, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(179.53043478260872, 97.07142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(184.38260869565218, 104.83714285714285, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(218.34782608695653, 112.60285714285713, 'X[1] <= 4630.5\ngini = 0.342\nsamples = 32\nvalue = [7, 25]'),
#  Text(198.9391304347826, 104.83714285714285, 'X[1] <= 4317.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(189.23478260869567, 97.07142857142857, 'X[0] <= 2.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(184.38260869565218, 89.30571428571429, 'X[1] <= 3589.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(179.53043478260872, 81.53999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(189.23478260869567, 81.53999999999999, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(194.08695652173915, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(208.64347826086959, 97.07142857142857, 'X[0] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(203.7913043478261, 89.30571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(213.49565217391307, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(237.75652173913045, 104.83714285714285, 'X[0] <= 2.5\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(228.0521739130435, 97.07142857142857, 'X[8] <= 0.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(223.20000000000002, 89.30571428571429, 'X[3] <= 126.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(218.34782608695653, 81.53999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(228.0521739130435, 81.53999999999999, 'X[1] <= 6315.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(223.20000000000002, 73.7742857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(232.90434782608696, 73.7742857142857, 'X[10] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(228.0521739130435, 66.00857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(237.75652173913045, 66.00857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(232.90434782608696, 89.30571428571429, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(247.46086956521742, 97.07142857142857, 'X[3] <= 111.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(242.60869565217394, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(252.31304347826088, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(203.7913043478261, 128.1342857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(181.95652173913044, 143.66571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(271.7217391304348, 151.43142857142857, 'X[3] <= 139.0\ngini = 0.32\nsamples = 105\nvalue = [21, 84]'),
#  Text(262.0173913043478, 143.66571428571427, 'X[2] <= 708.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(257.1652173913044, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(266.8695652173913, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(281.4260869565218, 143.66571428571427, 'X[1] <= 1730.5\ngini = 0.303\nsamples = 102\nvalue = [19, 83]'),
#  Text(276.5739130434783, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(286.27826086956526, 135.89999999999998, 'X[3] <= 277.0\ngini = 0.293\nsamples = 101\nvalue = [18, 83]'),
#  Text(281.4260869565218, 128.1342857142857, 'X[2] <= 120.0\ngini = 0.325\nsamples = 88\nvalue = [18, 70]'),
#  Text(252.31304347826088, 120.36857142857143, 'X[1] <= 3892.5\ngini = 0.424\nsamples = 36\nvalue = [11, 25]'),
#  Text(247.46086956521742, 112.60285714285713, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(257.1652173913044, 112.60285714285713, 'X[1] <= 5910.5\ngini = 0.408\nsamples = 35\nvalue = [10, 25]'),
#  Text(252.31304347826088, 104.83714285714285, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(262.0173913043478, 104.83714285714285, 'X[4] <= 210.0\ngini = 0.437\nsamples = 31\nvalue = [10, 21]'),
#  Text(257.1652173913044, 97.07142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(266.8695652173913, 97.07142857142857, 'X[4] <= 300.0\ngini = 0.452\nsamples = 29\nvalue = [10, 19]'),
#  Text(262.0173913043478, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(271.7217391304348, 89.30571428571429, 'X[10] <= 0.5\ngini = 0.436\nsamples = 28\nvalue = [9, 19]'),
#  Text(266.8695652173913, 81.53999999999999, 'X[0] <= 2.5\ngini = 0.469\nsamples = 24\nvalue = [9, 15]'),
#  Text(262.0173913043478, 73.7742857142857, 'X[0] <= 1.5\ngini = 0.454\nsamples = 23\nvalue = [8, 15]'),
#  Text(257.1652173913044, 66.00857142857143, 'X[3] <= 259.5\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(252.31304347826088, 58.24285714285713, 'X[3] <= 158.0\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(247.46086956521742, 50.47714285714284, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(257.1652173913044, 50.47714285714284, 'X[1] <= 11041.5\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(252.31304347826088, 42.71142857142857, 'X[9] <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(247.46086956521742, 34.945714285714274, 'X[8] <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(232.90434782608696, 27.17999999999998, 'X[6] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(228.0521739130435, 19.41428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(237.75652173913045, 19.41428571428571, 'X[1] <= 8866.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(232.90434782608696, 11.648571428571415, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(242.60869565217394, 11.648571428571415, 'X[1] <= 9787.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(237.75652173913045, 3.8828571428571195, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(247.46086956521742, 3.8828571428571195, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(262.0173913043478, 27.17999999999998, 'X[3] <= 167.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(257.1652173913044, 19.41428571428571, 'X[1] <= 7295.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(252.31304347826088, 11.648571428571415, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(262.0173913043478, 11.648571428571415, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(266.8695652173913, 19.41428571428571, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(257.1652173913044, 34.945714285714274, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(262.0173913043478, 42.71142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(262.0173913043478, 58.24285714285713, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(266.8695652173913, 66.00857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(271.7217391304348, 73.7742857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(276.5739130434783, 81.53999999999999, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(310.53913043478263, 120.36857142857143, 'X[3] <= 256.5\ngini = 0.233\nsamples = 52\nvalue = [7, 45]'),
#  Text(300.83478260869566, 112.60285714285713, 'X[1] <= 4173.0\ngini = 0.187\nsamples = 48\nvalue = [5, 43]'),
#  Text(295.9826086956522, 104.83714285714285, 'X[3] <= 189.0\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(286.27826086956526, 97.07142857142857, 'X[4] <= 270.0\ngini = 0.236\nsamples = 22\nvalue = [3, 19]'),
#  Text(281.4260869565218, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(291.13043478260875, 89.30571428571429, 'X[1] <= 3692.0\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(286.27826086956526, 81.53999999999999, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(295.9826086956522, 81.53999999999999, 'X[1] <= 3783.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(291.13043478260875, 73.7742857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(300.83478260869566, 73.7742857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(305.68695652173915, 97.07142857142857, 'X[3] <= 204.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(300.83478260869566, 89.30571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(310.53913043478263, 89.30571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(305.68695652173915, 104.83714285714285, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(320.2434782608696, 112.60285714285713, 'X[2] <= 3223.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(315.3913043478261, 104.83714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(325.0956521739131, 104.83714285714285, 'X[3] <= 258.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(320.2434782608696, 97.07142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(329.9478260869565, 97.07142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(291.13043478260875, 128.1342857142857, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(291.13043478260875, 159.19714285714286, 'X[1] <= 2285.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(286.27826086956526, 151.43142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(295.9826086956522, 151.43142857142857, 'X[3] <= 109.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(291.13043478260875, 143.66571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(300.83478260869566, 143.66571428571427, 'X[9] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(295.9826086956522, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(305.68695652173915, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(267.4760869565218, 166.96285714285713, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(277.1804347826087, 198.0257142857143, 'X[0] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(272.3282608695652, 190.26, 'X[2] <= 26918.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(267.4760869565218, 182.4942857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(277.1804347826087, 182.4942857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(282.0326086956522, 190.26, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %% [markdown]
# # Text Representation

# %%
text_representation = tree.export_text(model)

print(text_representation)
# Out:
# |--- feature_5 <= 0.50
# |   |--- feature_2 <= 8115.00
# |   |   |--- feature_3 <= 160.50
# |   |   |   |--- feature_4 <= 240.00
# |   |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_4 >  240.00
# |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  160.50
# |   |   |   |--- feature_3 <= 172.00
# |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  172.00
# |   |   |   |   |--- class: 0
# |   |--- feature_2 >  8115.00
# |   |   |--- feature_8 <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- feature_8 >  0.50
# |   |   |   |--- class: 0
# |--- feature_5 >  0.50
# |   |--- feature_2 <= 9650.50
# |   |   |--- feature_6 <= 0.50
# |   |   |   |--- feature_3 <= 302.00
# |   |   |   |   |--- feature_3 <= 85.50
# |   |   |   |   |   |--- feature_3 <= 51.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  51.50
# |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 60.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  60.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 76.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  76.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  85.50
# |   |   |   |   |   |--- feature_2 <= 3026.50
# |   |   |   |   |   |   |--- feature_1 <= 587.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  587.50
# |   |   |   |   |   |   |   |--- feature_1 <= 18596.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 420.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2992.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6391.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  6391.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  2992.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  420.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  18596.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  3026.50
# |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  302.00
# |   |   |   |   |--- feature_0 <= 1.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  1.00
# |   |   |   |   |   |--- feature_3 <= 345.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  345.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_6 >  0.50
# |   |   |   |--- feature_4 <= 60.00
# |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_4 >  60.00
# |   |   |   |   |--- feature_3 <= 13.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  13.00
# |   |   |   |   |   |--- feature_2 <= 7480.00
# |   |   |   |   |   |   |--- feature_4 <= 420.00
# |   |   |   |   |   |   |   |--- feature_3 <= 137.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 5708.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3798.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  3798.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  5708.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  137.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 139.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 708.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  708.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  139.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1730.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1730.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 277.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  277.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  420.00
# |   |   |   |   |   |   |   |--- feature_1 <= 2285.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  2285.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 109.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  109.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  7480.00
# |   |   |   |   |   |   |--- class: 0
# |   |--- feature_2 >  9650.50
# |   |   |--- feature_0 <= 0.50
# |   |   |   |--- feature_2 <= 26918.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  26918.50
# |   |   |   |   |--- class: 0
# |   |   |--- feature_0 >  0.50
# |   |   |   |--- class: 0
