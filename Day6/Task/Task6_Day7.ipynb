# %% [markdown]
# ***NAME: SADDAM HUSSAIN***
#
# ***REG ID: GO_STP_6834***
#
# ---
#
#
#
# ---

# %% [markdown]
# 1. Load the necessary package for plotting using pyplot from matplotlib. Example - Days(x-axis) represents 8 days and Speed represents a car’s speed. Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.
#
# Days=[1,2,3,4,5,6,7,8]
#
# Speed=[60,62,61,58,56,57,46,63]​​​​​

# %%
from matplotlib import pyplot as plt

# %%
Days=[1,2,3,4,5,6,7,8]
Speed = [60,62,61,58,56,57,46,63]

plt.plot(Days,Speed)
plt.title("Car Speed Measurement")
plt.xlabel('Days')
plt.ylabel('Car Speed')

plt.show()

# %% [markdown]
# 2. Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc.

# %%
plt.plot(Days,Speed, 'g:',marker = '+', ms = 10, markerfacecolor = 'red')
#OR plt.plot(Days,Speed,'g:+', ms = 20)
plt.title("Car Speed Measurement")
plt.xlabel('Days')
plt.ylabel('Car Speed')

plt.show()

# %%
plt.plot(Days,Speed, 'g:',marker = 'p', markersize = 20, markerfacecolor = 'red')
#OR plt.plot(Days,Speed,'g:+', ms = 20)
#plt.plot(Days,Speed,color ='green', linestyle='dotted', marker='o', markerfacecolor = 'blue', markersize=12)
plt.title("Car Speed Measurement")
plt.xlabel('Days')
plt.ylabel('Car Speed')

plt.show()

# %% [markdown]
# 3. Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.
#
# days=[1,2,3,4,5,6,7,8]
#
# max_speed=[80,91,92,88,77,79,76,75]
#
# min_speed=[42,43,40,42,33,36,34,35]
#
# avg_speed=[46,58,57,56,40,42,41,36]

# %%
days=[1,2,3,4,5,6,7,8]
max_speed=[80,91,92,88,77,79,76,75]
min_speed=[42,43,40,42,33,36,34,35]
avg_speed=[46,58,57,56,40,42,41,36]

plt.plot(days, max_speed,label = 'max_speed')
plt.plot(days, min_speed, label = 'min_speed')
plt.plot(days, avg_speed, label = 'avg_speed')

plt.title('Car Speed')
plt.xlabel('Days')
plt.ylabel('Speed')

plt.grid()
plt.show()

# %% [markdown]
# 4. Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.

# %%
import numpy as np

# %%
# Get x values of the sine wave
time = np.arange(0, 10, 0.1);
amp_sin = np.sin(time)

amp_cos = np.cos(time)
plt.subplot(211)
plt.plot(time, amp_sin)

plt.subplot(212)
plt.plot(time, amp_cos, 'g')

plt.show()

# %% [markdown]
# 5. Plot Simple bar chart showing popularity of Programming Languages.
#
# Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
#
# Popularity = [56, 39, 34, 34, 29]
#
# Security = [44 ,36 ,55, 50, 42]
#
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]

x_range = np.arange(len(Languages))

plt.bar(x_range - 0.2,Popularity,0.4, label = 'Popularity', color = 'g')
plt.bar(x_range + 0.2,Security,.4, label = 'Security', color = 'r')


plt.xticks(x_range, Languages)
plt.show()

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]

y_range = np.arange(len(Languages))

plt.barh(y_range - 0.2, Popularity,0.4, label = 'Popularity', color = 'g')
plt.barh(y_range + 0.2,Security,0.4, label = 'Security', color = 'r')


plt.yticks(y_range, Languages)
plt.show()

# %% [markdown]
# 6. Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.
#
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
#
# Histogram showing Below Average, Average and Execellent distribution
#
# 40-60: Below Average
#
# 60-80: Average
#
# 80-100: Excellent

# %%
Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]

bins = [40,60,80,100]
plt.hist(Marks,bins = bins)

count = [8,5,4]

#plt.xticks(bins = )
plt.xticks(bins, ['Below Average', 'Average', 'Excellent'], ha='left', rotation = 45)

plt.show()

# %% [markdown]
# 7. Titanic Data Set Download Data
#
#  Load the data file
#
#  (i) Create a pie chart presenting the male/female proportion
#
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/titanic.csv')

# %%
a = df.groupby('Sex').count()

# %%
data = a['PassengerId'].values

# %%
data
# Out:
# array([314, 577])

# %%
plt.pie(data,labels = ['Female', 'Male'] , startangle=180, autopct='%1.2f%%')

plt.show()

# %% [markdown]
# ii)

# %%
Fare = df['Fare']
Age = df['Age']

male = df[df['Sex'] == 'male']
#maleCount = male.Sex.count()
female = df[df['Sex'] == 'female']
#femaleCount = female.Sex.count()

plt.scatter(male.Fare,male.Age, color = 'r', label = 'male')
plt.scatter(female.Fare, female.Age, color = 'g', label = 'female')
plt.legend()
plt.title('Scatter plot')

plt.show()

# %%
#OR
colors = {'male':'b', 'female':'g'}
plt.scatter(df['Fare'],df['Age'], c = df['Sex'].map(colors))
plt.title('Scatter plot')

plt.show()
